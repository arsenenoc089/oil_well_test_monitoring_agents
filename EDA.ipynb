# %%
#anonymise PDF
import yaml

replacement_patterns = {
    r'\bMauddud\b': 'Internt',
    r'\bCA\b': 'AA',
    r'\bCD\b': 'BB',
    r'\bCE\b': 'CC',
    r'\bFC\b': 'ZZ',
    r'\bC-Location\b': 'A-Internet',
    r'\bLoc\b': 'Int',
    r'\bALS\b': 'ABC',
    r'\bAP\b': 'B1',
    r'\bKNA\b': 'BCD',
    r'\bOBN\b': 'XYZ',
    r'\bN110\b': 'XY11',
    r'\bN150\b': 'XY12',
}

# Add the scripts directory to the system path
sys.path.append(os.path.abspath('..'))

# Import the function from the scripts folder
from scripts.extract_pdf_text import anonymize_pdf

# Load the config
with open('../config/config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# Load the dataset
pdf_path = config['paths']['pdfPath']
output_path = config['paths']['pdfOPPath']
anonymize_pdf(pdf_path, output_path, replacement_patterns)
# Out:
# anonymize_pdf completed!

# %%
#data analysis
import sys
import os
import yaml

# Add the scripts directory to the system path
sys.path.append(os.path.abspath('..'))

# Import the function from the scripts folder
from scripts.data_exploration import data_exploration

# Load the config
with open('../config/config.yaml', 'r') as file:
    config = yaml.safe_load(file)

csv_path = config['paths']['WellCSVPath']
    
data_exploration(csv_path)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6461 entries, 0 to 6460
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                6460 non-null   object
#  1   WT GL               3136 non-null   float64
#  2   WT LIQ              3136 non-null   float64
#  3   WT Oil              3136 non-null   float64
#  4   WT THP              3136 non-null   float64
#  5   WT WCT              3136 non-null   float64
#  6   Z1 BHP*10           1817 non-null   float64
#  7   Z2 BHP*10           1867 non-null   float64
#  8   Z3 BHP*10           1982 non-null   float64
#  9   Z4 BHP*10           1639 non-null   float64
#  10  Z6 BHP*10           0 non-null      float64
#  11  Z5 BHP*10           0 non-null      float64
#  12  Z7 BHP*10           0 non-null      float64
#  13  Forecast IB-25      18 non-null     float64
#  14  Forecast Last RoFo  13 non-null     float64
# ...
